# %%
import re

input = open('input.txt').read()
split_input = re.split(r'\$ cd .*\n\$ ls\n.[^(\$)]+', input)

for item in split_input:
    folder = re.search(r'(\$ cd (.*)\n\$ ls\n)(.[^(\$)]+)')
    folder_name = folder.group(2)
    folder_content = folder.group(3)

# %%
root_dir = [a_dir, b_txt, c_dat, d_dir]
a_dir = [e_dir, f, g, h_lst]
e_dir = [i]
i = [584]
b_txt = [14848514]
f = [29116]
g = [2557]
h_lst = [62596]
c_dat = [8504156]
d_dir = [j, d_log, d_ext, k]
j = [4060174]
d_log = [8033020]
d_ext = [5626152]
k = [7214296]

def calculate_size(folder):
    size = 0
    for item in folder:
        if isinstance(item[0], int):
            size += item[0]/
        elif isinstance(item[0], list):
            size += calculate_size(item)
    return size
